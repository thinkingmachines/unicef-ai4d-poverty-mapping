# %% [markdown]
# ---
# title: Rollout Model on Entire PH
# format:
#   html:
#     code-fold: false
# ---

# %%
# TODO
# model, feature_list = pickle.load(model_path)
# ph_tiles = generate_tiles()
# ookla_df = prepare_ookla()
# viirs_df = prepare_viirs()
# osm_df = prepare_osm()
# joined_df = join_df(ph_tiles, dhs_df, ookla_df, viirs_df, osm_df)
# joined_df["wealth_prediction"] = model.predict(joined_df["feature_list"])
