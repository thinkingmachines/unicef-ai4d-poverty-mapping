# %% [markdown]
# ---
# title: Prepare PH Data
# format:
#   html:
#     code-fold: false
# ---

# %%
# TODO
# dhs_df = prepare_dhs()
# ookla_df = prepare_ookla()
# viirs_df = prepare_viirs()
# osm_df = prepare_osm()
# joined_df = join_df(dhs_df, ookla_df, viirs_df, osm_df)
